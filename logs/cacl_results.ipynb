# %%
# BRITS
import numpy as np

# METR-LA MAR
mae_list=[7.211081027984619,7.243441104888916,7.261280059814453]
rmse_list=[13.632728576660156,13.731390953063965,13.763521194458008]
mape_list = [0.17157858610153198, 0.17342150211334229, 0.17399021983146667]
print("METR-LA MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)

# METR-LA MNAR
mae_list=[7.2106451988220215,7.217462062835693,7.185791492462158]
rmse_list=[12.989046096801758,13.028376579284668,13.017233848571777]
mape_list = [0.15964128077030182, 0.16051776707172394, 0.15990795195102692]
print("METR-LA MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)

# Seattle MAR
mae_list=[4.945061683654785,4.92920446395874,4.926028251647949]
rmse_list=[8.633832931518555,8.595694541931152,8.616804122924805]
mape_list = [0.18844041228294373, 0.1870448887348175, 0.18799687922000885]
print("Seattle MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)

# Seattle MNAR
mae_list=[4.6827497482299805,4.677504539489746,4.648013591766357]
rmse_list=[8.039005279541016,8.021580696105957,7.962702751159668]
mape_list = [0.16761934757232666, 0.1669166535139084, 0.16492721438407898]
print("Seattle MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)

# Chengdu MAR
mae_list=[3.2653238773345947,3.2408487796783447,3.230851888656616]
rmse_list=[4.664034843444824,4.629337787628174,4.623693943023682]
mape_list = [0.15029022097587585, 0.14875046908855438, 0.149684876203537]
print("Chengdu MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)

# Chengdu MNAR
mae_list=[3.1385459899902344,3.1267130374908447,3.1393277645111084]
rmse_list=[4.524018287658691,4.4788689613342285,4.509937286376953]
mape_list = [0.14560489356517792, 0.14385050535202026, 0.14580245316028595]
print("Chengdu MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)

# Shenzhen MAR
mae_list=[2.984121084213257,2.956601142883301,2.965503692626953]
rmse_list=[4.3918538093566895,4.33109188079834,4.354481220245361]
mape_list = [0.12082544714212418, 0.11895839869976044, 0.12014477699995041]
print("Shenzhen MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)

# Shenzhen MNAR
mae_list=[2.86207914352417,2.842350482940674,2.825174570083618]
rmse_list=[4.188515663146973,4.169498920440674,4.170328140258789]
mape_list = [0.11661184579133987, 0.11556773632764816, 0.11556103825569153]
print("Shenzhen MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)


# PEMS-BAY MAR
mae_list=[3.16003155708313,3.164219379425049,3.164733648300171]
rmse_list=[6.583711624145508,6.581462860107422,6.578636646270752]
mape_list = [0.08898300677537918, 0.08900398761034012, 0.08888071030378342]
print("PEMS-BAY MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)

# PEMS-BAY MNAR
mae_list=[2.9310970306396484,2.9264068603515625,2.926462173461914]
rmse_list=[5.924427509307861,5.892951011657715,5.931692600250244]
mape_list = [0.07821239531040192, 0.077634796500206, 0.07788021117448807]
print("PEMS-BAY MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)
# Out:
# METR-LA MAR
# mean of MAE: 7.238600730895996
# mean of RMSE: 13.709213574727377
# mean of MAPE: 17.29967693487803
# ==================================================
# METR-LA MNAR
# mean of MAE: 7.204632918039958
# mean of RMSE: 13.011552174886068
# mean of MAPE: 16.00223332643509
# ==================================================
# Seattle MAR
# mean of MAE: 4.933431466420491
# mean of RMSE: 8.61544386545817
# mean of MAPE: 18.782739341259003
# ==================================================
# Seattle MNAR
# mean of MAE: 4.669422626495361
# mean of RMSE: 8.007762908935547
# mean of MAPE: 16.648773849010468
# ==================================================
# Chengdu MAR
# mean of MAE: 3.2456748485565186
# mean of RMSE: 4.63902219136556
# mean of MAPE: 14.957518875598907
# ==================================================
# Chengdu MNAR
# mean of MAE: 3.134862263997396
# mean of RMSE: 4.504274845123291
# mean of MAPE: 14.508595069249472
# ==================================================
# Shenzhen MAR
# mean of MAE: 2.9687419732411704
# mean of RMSE: 4.359142303466797
# mean of MAPE: 11.9976207613945
# ==================================================
# Shenzhen MNAR
# mean of MAE: 2.8432013988494873
# mean of RMSE: 4.1761142412821455
# mean of MAPE: 11.591354012489319
# ==================================================
# PEMS-BAY MAR
# mean of MAE: 3.162994861602783
# mean of RMSE: 6.5812703768412275
# mean of MAPE: 8.895590156316757
# ==================================================
# PEMS-BAY MNAR
# mean of MAE: 2.9279886881510415
# mean of RMSE: 5.916357040405273
# mean of MAPE: 7.790913432836533
# ==================================================

# %%
# GRIN
import numpy as np

# METR-LA MAR
mae_list=[3.4717345237731934,3.4643590450286865,3.466287612915039]
rmse_list=[6.3178229331970215,6.305944442749023,6.314592361450195]
mape_list = [0.07597138732671738, 0.0760512575507164, 0.0764961689710617]
print("METR-LA MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)

# METR-LA MNAR
mae_list=[3.677175521850586,3.912534713745117,3.681567907333374]
rmse_list=[6.588428020477295,7.501389503479004,6.60023832321167]
mape_list = [0.08236037939786911, 0.08824567496776581, 0.08275824040174484]
print("METR-LA MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)

# Seattle MAR
mae_list=[2.5909578800201416,2.5898571014404297,2.589528799057007]
rmse_list=[4.055987358093262,4.053345203399658,4.066956520080566]
mape_list = [0.07049182057380676, 0.07062721997499466, 0.07058729976415634]
print("Seattle MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)

# Seattle MNAR

# Chengdu MAR
# 'mae': 2.631974697113037,
#  'mape': 0.11246400326490402,
#  'rmse': 3.7148187160491943,

# Chengdu MNAR
mae_list=[3.0092737674713135,3.009169816970825,3.002829074859619]
rmse_list=[4.159493446350098,4.159430503845215,4.146699905395508]
mape_list = [0.13100501894950867, 0.13048969209194183, 0.12960800528526306]
print("Chengdu MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)

# Shenzhen MAR

# Shenzhen MNAR
mae_list=[2.418333053588867,2.425905466079712,2.4102978706359863]
rmse_list=[3.523472785949707,3.5283470153808594,3.5218088626861572]
mape_list = [0.09377463907003403, 0.09458433091640472, 0.09437235444784164]
print("Shenzhen MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)


# PEMS-BAY MAR
mae_list=[1.1461775302886963,1.146087408065796,1.1860361099243164]
rmse_list=[2.5509181022644043,2.570971965789795,2.566312789916992]
mape_list = [0.0272198598831892, 0.027437174692749977, 0.027786491438746452]
print("PEMS-BAY MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)

# PEMS-BAY MNAR
mae_list=[1.2719197273254395,1.2772023677825928,1.4782984256744385]
rmse_list=[2.5724453926086426,2.585977077484131,3.168318748474121]
mape_list = [0.02870194800198078, 0.028906848281621933, 0.03602958098053932]
print("PEMS-BAY MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list)*100)
print("=" * 50)
# Out:
# METR-LA MAR
# mean of MAE: 3.4674603939056396
# mean of RMSE: 6.31278657913208
# mean of MAPE: 7.617293794949849
# ==================================================
# METR-LA MNAR
# mean of MAE: 3.7570927143096924
# mean of RMSE: 6.896685282389323
# mean of MAPE: 8.44547649224599
# ==================================================
# Seattle MAR
# mean of MAE: 2.5901145935058594
# mean of RMSE: 4.058763027191162
# mean of MAPE: 7.056878010431926
# ==================================================
# Chengdu MNAR
# mean of MAE: 3.0070908864339194
# mean of RMSE: 4.1552079518636065
# mean of MAPE: 13.036757210890451
# ==================================================
# Shenzhen MNAR
# mean of MAE: 2.4181787967681885
# mean of RMSE: 3.5245428880055747
# mean of MAPE: 9.424377481142681
# ==================================================
# PEMS-BAY MAR
# mean of MAE: 1.1594336827596028
# mean of RMSE: 2.562734285990397
# mean of MAPE: 2.748117533822854
# ==================================================
# PEMS-BAY MNAR
# mean of MAE: 1.3424735069274902
# mean of RMSE: 2.775580406188965
# mean of MAPE: 3.121279242138068
# ==================================================

# %%
# GA-GAN
import numpy as np

# METR-LA MAR
mae_list=[3.8172121047973633,3.8560101985931396,3.8922367095947266]
rmse_list=[6.76105260848999,6.72930383682251,6.8200554847717285]
mape_list = [8.302476064246397, 8.326843766123364, 8.485239557066862]
print("METR-LA MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# METR-LA MNAR
mae_list=[3.8477871417999268,3.8644826412200928,3.860224485397339]
rmse_list=[7.26519250869751,7.282288074493408,7.231436252593994]
mape_list = [8.402155394256788, 8.430931485893609, 8.400367845664716]
print("METR-LA MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Seattle MAR
mae_list=[2.558213472366333,2.551187753677368,2.572345733642578]
rmse_list=[3.7793374061584473,3.7608859539031982,3.7908663749694824]
mape_list = [6.25240443308333, 6.224959348241519, 6.264897564433484]
print("Seattle MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Seattle MNAR
mae_list=[2.5478289127349854,2.562756299972534,2.5547292232513428]
rmse_list=[3.8555586338043213,3.8792612552642822,3.8676536083221436]
mape_list = [6.180292194964827, 6.259786362583915, 6.206159498841387]
print("Seattle MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Chengdu MAR
mae_list=[2.129624128341675,2.6713640689849854,2.1158783435821533]
rmse_list=[3.0968093872070312,3.728817939758301,3.078723907470703]
mape_list = [9.074927172024738, 11.95040132866635, 9.030421055692587]
print("Chengdu MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Chengdu MNAR
mae_list=[2.368884801864624,2.3712997436523438,2.399430274963379]
rmse_list=[3.5079457759857178,3.509572982788086,3.5405216217041016]
mape_list = [10.082822511630914, 10.104073500721306, 10.216301111226006]
print("Chengdu MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Shenzhen MAR
mae_list=[1.9341566562652588,1.8773943185806274,1.887354850769043]
rmse_list=[2.8379454612731934,2.788674831390381,2.7905054092407227]
mape_list = [7.84941035580487, 7.702809752458055, 7.696488647656392]
print("Shenzhen MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Shenzhen MNAR
mae_list=[2.2497215270996094,2.2712128162384033,2.259697675704956]
rmse_list=[3.4245316982269287,3.4334230422973633,3.438110113143921]
mape_list = [9.32339022081574, 9.442869349413098, 9.280136823189716]
print("Shenzhen MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# PEMS-BAY MAR
mae_list=[1.0178544521331787,1.0070477724075317,1.0189177989959717]
rmse_list=[1.8400213718414307,1.8339014053344727,1.8558521270751953]
mape_list = [2.0746200702276774, 2.051539939914305, 2.090100553278153]
print("PEMS-BAY MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# PEMS-BAY MNAR
mae_list=[1.135233998298645,1.1345964670181274,1.1299926042556763]
rmse_list=[2.2161083221435547,2.2149693965911865,2.217806339263916]
mape_list = [2.3297827099999457, 2.3318845928280507, 2.3109473102377285]
print("PEMS-BAY MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)
# Out:
# METR-LA MAR
# mean of MAE: 3.8551530043284097
# mean of RMSE: 6.770137310028076
# mean of MAPE: 8.371519795812207
# ==================================================
# METR-LA MNAR
# mean of MAE: 3.8574980894724527
# mean of RMSE: 7.259638945261638
# mean of MAPE: 8.411151575271704
# ==================================================
# Seattle MAR
# mean of MAE: 2.5605823198954263
# mean of RMSE: 3.7770299116770425
# mean of MAPE: 6.247420448586112
# ==================================================
# Seattle MNAR
# mean of MAE: 2.5551048119862876
# mean of RMSE: 3.8674911657969155
# mean of MAPE: 6.215412685463376
# ==================================================
# Chengdu MAR
# mean of MAE: 2.305622180302938
# mean of RMSE: 3.3014504114786782
# mean of MAPE: 10.018583185461225
# ==================================================
# Chengdu MNAR
# mean of MAE: 2.3798716068267822
# mean of RMSE: 3.5193467934926352
# mean of MAPE: 10.134399041192742
# ==================================================
# Shenzhen MAR
# mean of MAE: 1.8996352752049763
# mean of RMSE: 2.805708567301432
# mean of MAPE: 7.749569585306439
# ==================================================
# Shenzhen MNAR
# mean of MAE: 2.2602106730143228
# mean of RMSE: 3.4320216178894043
# mean of MAPE: 9.348798797806184
# ==================================================
# PEMS-BAY MAR
# mean of MAE: 1.0146066745122273
# mean of RMSE: 1.843258301417033
# mean of MAPE: 2.0720868544733784
# ==================================================
# PEMS-BAY MNAR
# mean of MAE: 1.1332743565241497
# mean of RMSE: 2.2162946859995523
# mean of MAPE: 2.3242048710219083
# ==================================================

# %%
# MISGAN
import numpy as np

# Chengdu MAR
mae_list=[2.518,2.517,2.522]
rmse_list=[3.664,3.675,3.660]
mape_list = [11.403,11.448,11.345]
print("Chengdu MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Chengdu MNAR
mae_list=[2.564,2.550,2.564]
rmse_list=[3.744,3.730,3.747]
mape_list = [11.721,11.671,11.672]
print("Chengdu MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# METR-LA MAR
mae_list=[5.889,5.938,5.951]
rmse_list=[10.524,10.495,10.473]
mape_list = [11.512,11.506,11.597]
print("METR-LA MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# METR-LA MNAR
mae_list=[5.616,5.634,5.663]
rmse_list=[10.333,10.348,10.333]
mape_list = [11.359,11.379,11.414]
print("METR-LA MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# PEMS-BAY MAR
mae_list=[2.226,2.218,2.229]
rmse_list=[4.121,4.076,4.099]
mape_list = [5.051,4.984,5.027]
print("PEMS-BAY MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# PEMS-BAY MNAR
mae_list=[2.323,2.279]
rmse_list=[4.573,4.378]
mape_list = [5.461,5.278]
print("PEMS-BAY MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Seattle MAR
mae_list=[3.568,3.581,3.564]
rmse_list=[5.581,5.551,5.573]
mape_list = [10.110,10.163,10.136]
print("Seattle MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Seattle MNAR
mae_list=[3.642,3.643,3.638]
rmse_list=[5.813,5.811,5.805]
mape_list = [10.691,10.631,10.578]
print("Seattle MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# Shenzhen MAR
mae_list=[2.237,2.245,2.241]
rmse_list=[3.447,3.457,3.436]
mape_list = [9.535,9.584,9.536]
print("Shenzhen MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Shenzhen MNAR
mae_list=[2.265,2.272,2.275]
rmse_list=[3.502,3.514,3.511]
mape_list = [9.790,9.840,9.750]
print("Shenzhen MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)
# Out:
# Chengdu MAR
# mean of MAE: 2.519
# mean of RMSE: 3.6663333333333337
# mean of MAPE: 11.398666666666665
# ==================================================
# Chengdu MNAR
# mean of MAE: 2.5593333333333335
# mean of RMSE: 3.7403333333333335
# mean of MAPE: 11.688
# ==================================================
# METR-LA MAR
# mean of MAE: 5.925999999999999
# mean of RMSE: 10.497333333333332
# mean of MAPE: 11.538333333333334
# ==================================================
# METR-LA MNAR
# mean of MAE: 5.637666666666667
# mean of RMSE: 10.338000000000001
# mean of MAPE: 11.384
# ==================================================
# PEMS-BAY MAR
# mean of MAE: 2.2243333333333335
# mean of RMSE: 4.0986666666666665
# mean of MAPE: 5.020666666666667
# ==================================================
# PEMS-BAY MNAR
# mean of MAE: 2.301
# mean of RMSE: 4.4755
# mean of MAPE: 5.3695
# ==================================================
# Seattle MAR
# mean of MAE: 3.571
# mean of RMSE: 5.568333333333334
# mean of MAPE: 10.136333333333333
# ==================================================
# Seattle MNAR
# mean of MAE: 3.641
# mean of RMSE: 5.809666666666666
# mean of MAPE: 10.633333333333335
# ==================================================
# Shenzhen MAR
# mean of MAE: 2.241
# mean of RMSE: 3.4466666666666668
# mean of MAPE: 9.551666666666668
# ==================================================
# Shenzhen MNAR
# mean of MAE: 2.2706666666666666
# mean of RMSE: 3.5090000000000003
# mean of MAPE: 9.793333333333333
# ==================================================

# %%
# STGCN
import numpy as np

# Chengdu MAR
mae_list=[2.369,2.437,2.378]
rmse_list=[3.347,3.431,3.361]
mape_list = [10.311,10.669,10.458]
print("Chengdu MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Chengdu MNAR
mae_list=[2.635,2.690,2.758]
rmse_list=[3.757,3.813,3.898]
mape_list = [11.558,11.657,12.214]
print("Chengdu MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# METR-LA MAR
mae_list=[4.095,4.127,4.312]
rmse_list=[7.428,7.256,7.540]
mape_list = [8.733,8.998,9.136]
print("METR-LA MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# METR-LA MNAR
mae_list=[4.253,4.446,4.286]
rmse_list=[7.490,7.838,7.795]
mape_list = [9.233,9.737,9.447]
print("METR-LA MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# PEMS-BAY MAR
mae_list=[1.671,1.799,1.572]
rmse_list=[2.772,3.053,2.641]
mape_list = [3.286,3.683,3.160]
print("PEMS-BAY MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# PEMS-BAY MNAR
mae_list=[1.931,1.992,1.829]
rmse_list=[3.324,3.349,3.165]
mape_list = [3.875,3.992,3.683]
print("PEMS-BAY MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# Seattle MAR
mae_list=[2.618,2.520,2.675]
rmse_list=[3.890,3.771,3.985]
mape_list = [6.295,6.099,6.458]
print("Seattle MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Seattle MNAR
mae_list=[2.706,2.692,2.666]
rmse_list=[4.098,4.055,4.055]
mape_list = [6.688,6.447,6.450]
print("Seattle MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Shenzhen MAR
mae_list=[2.303,2.339,2.294]
rmse_list=[3.285,3.353,3.274]
mape_list = [9.684,9.927,9.660]
print("Shenzhen MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Shenzhen MNAR
mae_list=[2.572,2.496,2.577]
rmse_list=[3.718,3.625,3.724]
mape_list = [10.807,10.565,10.837]
print("Shenzhen MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)
# Out:
# Chengdu MAR
# mean of MAE: 2.3946666666666667
# mean of RMSE: 3.379666666666667
# mean of MAPE: 10.479333333333335
# ==================================================
# Chengdu MNAR
# mean of MAE: 2.694333333333333
# mean of RMSE: 3.8226666666666667
# mean of MAPE: 11.809666666666667
# ==================================================
# METR-LA MAR
# mean of MAE: 4.178
# mean of RMSE: 7.408
# mean of MAPE: 8.955666666666668
# ==================================================
# METR-LA MNAR
# mean of MAE: 4.328333333333333
# mean of RMSE: 7.7076666666666656
# mean of MAPE: 9.472333333333333
# ==================================================
# PEMS-BAY MAR
# mean of MAE: 1.6806666666666665
# mean of RMSE: 2.8219999999999996
# mean of MAPE: 3.376333333333333
# ==================================================
# PEMS-BAY MNAR
# mean of MAE: 1.9173333333333333
# mean of RMSE: 3.2793333333333337
# mean of MAPE: 3.85
# ==================================================
# Seattle MAR
# mean of MAE: 2.6043333333333334
# mean of RMSE: 3.8819999999999997
# mean of MAPE: 6.284
# ==================================================
# Seattle MNAR
# mean of MAE: 2.688
# mean of RMSE: 4.069333333333333
# mean of MAPE: 6.528333333333333
# ==================================================
# Shenzhen MAR
# mean of MAE: 2.312
# mean of RMSE: 3.304
# mean of MAPE: 9.757
# ==================================================
# Shenzhen MNAR
# mean of MAE: 2.5483333333333333
# mean of RMSE: 3.689
# mean of MAPE: 10.736333333333334
# ==================================================

# %%
# DCRNN
# Chengdu MAR
Test MAE: 2.128008577558729 RMSE: 3.0936858124203153 MAPE: 8.95009943180614
# Chengdu MNAR
Test MAE: 2.4624300797780356 RMSE: 3.744725889629788 MAPE: 10.583147986067667
# METR-LA MAR
Test MAE: 4.325670391321182 RMSE: 10.381286025047302 MAPE: 6.357185123488307
# METR-LA MNAR
Test MAE: 6.272795885801315 RMSE: 14.037917017936707 MAPE: 6.811859318986535
# PEMS-BAY MAR
Test MAE: 0.9449733908359821 RMSE: 1.743184153850262 MAPE: 1.856125296595005
# PEMS-BAY MNAR
Test MAE: 1.1269977642939641 RMSE: 2.291994104018578 MAPE: 2.2249724071186323

# Seattle MAR
Test MAE: 2.1084721044257835 RMSE: 3.233336607615153 MAPE: 4.905140199870975
# Seattle MNAR
Test MAE: 2.2025477444684065 RMSE: 3.4750839515968606 MAPE: 5.1626741196270345

# Shenzhen MAR
Test MAE: 1.8002001576953464 RMSE: 2.6847871674431696 MAPE: 7.221004532443152
# Shenzhen MNAR
Test MAE: 2.16751758257548 RMSE: 3.5091811550988092 MAPE: 8.590611898236805

# %%
# Graph WaveNet
import numpy as np
# Chengdu MAR
mae_list=[2.194,2.078,2.136]
rmse_list=[3.184,3.053,3.125]
mape_list = [9.442,8.856,9.221]
print("Chengdu MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Chengdu MNAR
mae_list=[2.469,2.459,2.456]
rmse_list=[3.771,3.778,3.767]
mape_list = [10.481,10.422,10.590]
print("Chengdu MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# METR-LA MAR
mae_list=[3.032,3.012,3.152]
rmse_list=[6.066,6.116,6.330]
mape_list = [6.584,6.530,7.213]
print("METR-LA MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# METR-LA MNAR
mae_list=[3.198,3.205,3.303]
rmse_list=[7.221,7.243,7.260]
mape_list = [7.068,7.118,7.384]
print("METR-LA MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# PEMS-BAY MAR
mae_list=[0.941,0.911,0.944]
rmse_list=[1.700,1.682,1.721]
mape_list = [1.845,1.793,1.861]
print("PEMS-BAY MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# PEMS-BAY MNAR
mae_list=[1.056,1.028,1.029]
rmse_list=[2.203,2.166,2.172]
mape_list = [2.132,2.056,2.063]
print("PEMS-BAY MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# Seattle MAR
mae_list=[2.467,2.454,2.452]
rmse_list=[3.742,3.780,3.737]
mape_list = [5.812,5.749,5.771]
print("Seattle MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Seattle MNAR
mae_list=[2.561,2.624,2.582]
rmse_list=[4.028,4.165,4.081]
mape_list = [6.089,6.300,6.097]
print("Seattle MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# Shenzhen MAR
mae_list=[1.840,1.851,1.838]
rmse_list=[2.745,2.758,2.747]
mape_list = [7.466,7.528,7.374]
print("Shenzhen MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Shenzhen MNAR
mae_list=[2.217,2.224,2.225]
rmse_list=[3.605,3.620,3.614]
mape_list = [9.017,9.030,9.138]
print("Shenzhen MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)
# Out:
# Chengdu MAR
# mean of MAE: 2.136
# mean of RMSE: 3.1206666666666667
# mean of MAPE: 9.173
# ==================================================
# Chengdu MNAR
# mean of MAE: 2.4613333333333336
# mean of RMSE: 3.772
# mean of MAPE: 10.497666666666666
# ==================================================
# METR-LA MAR
# mean of MAE: 3.0653333333333337
# mean of RMSE: 6.1706666666666665
# mean of MAPE: 6.775666666666667
# ==================================================
# METR-LA MNAR
# mean of MAE: 3.235333333333333
# mean of RMSE: 7.241333333333333
# mean of MAPE: 7.19
# ==================================================
# PEMS-BAY MAR
# mean of MAE: 0.9319999999999999
# mean of RMSE: 1.7009999999999998
# mean of MAPE: 1.833
# ==================================================
# PEMS-BAY MNAR
# mean of MAE: 1.0376666666666667
# mean of RMSE: 2.1803333333333335
# mean of MAPE: 2.0836666666666672
# ==================================================
# Seattle MAR
# mean of MAE: 2.457666666666667
# mean of RMSE: 3.753
# mean of MAPE: 5.777333333333334
# ==================================================
# Seattle MNAR
# mean of MAE: 2.589
# mean of RMSE: 4.091333333333334
# mean of MAPE: 6.162
# ==================================================
# Shenzhen MAR
# mean of MAE: 1.843
# mean of RMSE: 2.75
# mean of MAPE: 7.4559999999999995
# ==================================================
# Shenzhen MNAR
# mean of MAE: 2.222
# mean of RMSE: 3.6129999999999995
# mean of MAPE: 9.061666666666666
# ==================================================

# %%
# D2STGNN
import numpy as np

# Chengdu MAR
mae_list=[2.14,2.14,2.10]
rmse_list=[3.08,3.09,3.05]
mape_list = [9.13,9.22,9.02]
print("Chengdu MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# Chengdu MNAR
mae_list=[2.18,2.17,2.17]
rmse_list=[3.20,3.20,3.20]
mape_list = [9.57,9.52,9.50]
print("Chengdu MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# METR-LA MAR
mae_list=[4.24,4.31,4.28]
rmse_list=[9.22,9.48,9.32]
mape_list = [6.59,6.52,6.50]
print("METR-LA MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# METR-LA MNAR
mae_list=[6.65,6.60,6.67]
rmse_list=[13.18,13.13,12.96]
mape_list = [6.78,6.52,6.79]
print("METR-LA MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# PEMS-BAY MAR
mae_list=[0.88,0.88,0.91]
rmse_list=[1.58,1.58,1.64]
mape_list = [1.81,1.84,1.96]
print("PEMS-BAY MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# PEMS-BAY MNAR
mae_list=[0.95,0.95,0.96]
rmse_list=[1.82,1.82,1.83]
mape_list = [1.98,1.99,2.05]
print("PEMS-BAY MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# Seattle MAR
mae_list=[2.21,2.25,2.18]
rmse_list=[3.34,3.38,3.30]
mape_list = [5.34,5.42,5.29]
print("Seattle MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# Seattle MNAR
mae_list=[2.21,2.20,2.22]
rmse_list=[3.45,3.44,3.46]
mape_list = [5.34,5.30,5.45]
print("Seattle MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Shenzhen MAR
mae_list=[1.91,1.85,1.86]
rmse_list=[2.79,2.72,2.73]
mape_list = [7.76,7.40,7.52]
print("Shenzhen MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Shenzhen MNAR
mae_list=[1.98,1.96,1.95]
rmse_list=[2.96,2.94,2.94]
mape_list = [8.19,8.08,8.05]
print("Shenzhen MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)
# Out:
# Chengdu MAR
# mean of MAE: 2.126666666666667
# mean of RMSE: 3.073333333333333
# mean of MAPE: 9.123333333333333
# ==================================================
# Chengdu MNAR
# mean of MAE: 2.1733333333333333
# mean of RMSE: 3.2000000000000006
# mean of MAPE: 9.53
# ==================================================
# METR-LA MAR
# mean of MAE: 4.276666666666667
# mean of RMSE: 9.340000000000002
# mean of MAPE: 6.536666666666666
# ==================================================
# METR-LA MNAR
# mean of MAE: 6.640000000000001
# mean of RMSE: 13.090000000000002
# mean of MAPE: 6.696666666666666
# ==================================================
# PEMS-BAY MAR
# mean of MAE: 0.89
# mean of RMSE: 1.5999999999999999
# mean of MAPE: 1.87
# ==================================================
# PEMS-BAY MNAR
# mean of MAE: 0.9533333333333333
# mean of RMSE: 1.8233333333333335
# mean of MAPE: 2.0066666666666664
# ==================================================
# Seattle MAR
# mean of MAE: 2.2133333333333334
# mean of RMSE: 3.34
# mean of MAPE: 5.3500000000000005
# ==================================================
# Seattle MNAR
# mean of MAE: 2.2100000000000004
# mean of RMSE: 3.4500000000000006
# mean of MAPE: 5.363333333333333
# ==================================================
# Shenzhen MAR
# mean of MAE: 1.8733333333333333
# mean of RMSE: 2.7466666666666666
# mean of MAPE: 7.56
# ==================================================
# Shenzhen MNAR
# mean of MAE: 1.9633333333333332
# mean of RMSE: 2.9466666666666668
# mean of MAPE: 8.106666666666667
# ==================================================

# %%
# DSTAGNN
import numpy as np

# Chengdu MAR
mae_list=[2.059,2.074,2.068]
rmse_list=[2.979,2.993,2.988]
mape_list = [8.825,8.935,8.928]
print("Chengdu MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Chengdu MNAR
mae_list=[2.184,2.162,2.170]
rmse_list=[3.179,3.155,3.183]
mape_list = [9.366,9.443,9.559]
print("Chengdu MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# METR-LA MAR
mae_list=[3.781,3.861,3.786]
rmse_list=[6.803,7.063,6.825]
mape_list = [7.912,7.753,7.597]
print("METR-LA MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# METR-LA MNAR
mae_list=[3.344,3.332,3.408]
rmse_list=[6.504,6.576,6.730]
mape_list = [7.734,7.541,7.671]
print("METR-LA MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# PEMS-BAY MAR
mae_list=[0.901,0.905,0.884]
rmse_list=[1.602,1.605,1.555]
mape_list = [1.777,1.816,1.764]
print("PEMS-BAY MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# PEMS-BAY MNAR
mae_list=[1.019,1.027,1.023]
rmse_list=[1.957,1.967,1.955]
mape_list = [2.045,2.045,2.052]
print("PEMS-BAY MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# Seattle MAR
mae_list=[2.467,2.477,2.433]
rmse_list=[3.697,3.704,3.640]
mape_list = [5.887,5.903,5.790]
print("Seattle MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Seattle MNAR


# Shenzhen MAR
mae_list=[1.878,1.866]
rmse_list=[2.744,2.709]
mape_list = [7.721,7.587]
print("Shenzhen MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# Shenzhen MNAR
mae_list=[1.979,1.967,1.975]
rmse_list=[2.931,2.929,2.944]
mape_list = [8.140,8.138,8.149]
print("Shenzhen MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)
# Out:
# Chengdu MAR
# mean of MAE: 2.067
# mean of RMSE: 2.9866666666666664
# mean of MAPE: 8.895999999999999
# ==================================================
# Chengdu MNAR
# mean of MAE: 2.172
# mean of RMSE: 3.172333333333333
# mean of MAPE: 9.455999999999998
# ==================================================
# METR-LA MAR
# mean of MAE: 3.8093333333333335
# mean of RMSE: 6.896999999999999
# mean of MAPE: 7.7540000000000004
# ==================================================
# METR-LA MNAR
# mean of MAE: 3.361333333333333
# mean of RMSE: 6.603333333333333
# mean of MAPE: 7.648666666666667
# ==================================================
# PEMS-BAY MAR
# mean of MAE: 0.8966666666666666
# mean of RMSE: 1.5873333333333333
# mean of MAPE: 1.7856666666666667
# ==================================================
# PEMS-BAY MNAR
# mean of MAE: 1.023
# mean of RMSE: 1.959666666666667
# mean of MAPE: 2.047333333333333
# ==================================================
# Seattle MAR
# mean of MAE: 2.459
# mean of RMSE: 3.6803333333333335
# mean of MAPE: 5.859999999999999
# ==================================================
# Shenzhen MAR
# mean of MAE: 1.8719999999999999
# mean of RMSE: 2.7265
# mean of MAPE: 7.654
# ==================================================
# Shenzhen MNAR
# mean of MAE: 1.9736666666666667
# mean of RMSE: 2.9346666666666663
# mean of MAPE: 8.142333333333333
# ==================================================

# %%
# PRISTI
# Chengdu MAR
MAE: 2.3873613841003842
RMSE: 3.5138825906647577
MAPE: 0.0987330370893081
# Chengdu MNAR
MAE: 2.217595693137911
RMSE: 3.523367338710361
MAPE: 0.09183207940724161
# METR-LA MAR
MAE: 2.696246176958084
RMSE: 5.495550917254554
MAPE: 0.06346215587109327
# METR-LA MNAR
MAE: 2.618304216199451
RMSE: 5.649220334159003
MAPE: 0.06412504530615276
# PEMS-BAY MAR
MAE: 0.8379574550522698
RMSE: 1.5056185258759394
MAPE: 0.015967077610117418
# PEMS-BAY MNAR
MAE: 0.9498832148534281
RMSE: 1.8230153807887324
MAPE: 0.018397098769330315
# Seattle MAR
MAE: 2.4558245171200146
RMSE: 3.7539239579981025
MAPE: 0.05502234143628316
# Seattle MNAR
MAE: 2.550233822519129
RMSE: 3.9767917719754307
MAPE: 0.05840710211883892
# Shenzhen MAR
MAE: 2.138959358135859
RMSE: 3.1517828835381403
MAPE: 0.08506903859476249
# Shenzhen MNAR
MAE: 2.1250668664773307
RMSE: 3.3054745727115207
MAPE: 0.08422519038948748

# %%
# McFlow
import numpy as np
# Chengdu MAR
mae_list=[2.684,2.859]
rmse_list=[3.877,4.116]
mape_list = [12.360,13.272]
print("Chengdu MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Chengdu MNAR
mae_list=[2.633,2.617]
rmse_list=[3.815,3.801]
mape_list = [11.968,11.878]
print("Chengdu MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# METR-LA MAR
mae_list=[6.841,6.904]
rmse_list=[11.985,12.100]
mape_list = [13.389,13.603]
print("METR-LA MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# METR-LA MNAR
# MAE 6.425 RMSE 11.450 MAPE 12.688

# PEMS-BAY MAR
# MAE 2.526 RMSE 4.763 MAPE 5.655

# PEMS-BAY MNAR
mae_list=[2.434,2.493]
rmse_list=[4.656,4.718]
mape_list = [5.476,5.562]
print("PEMS-BAY MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Seattle MAR
# MAE 4.048 RMSE 6.530 MAPE 11.362

# Seattle MNAR
mae_list=[3.970,3.897]
rmse_list=[6.378,6.233]
mape_list = [11.154,10.898]
print("Seattle MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)


# Shenzhen MAR
# MAE 2.626 RMSE 3.982 MAPE 11.229

# Shenzhen MNAR
mae_list=[2.550,2.597]
rmse_list=[3.852,3.912]
mape_list = [11.013,11.137]
print("Shenzhen MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)
# Out:
# Chengdu MAR
# mean of MAE: 2.7715
# mean of RMSE: 3.9964999999999997
# mean of MAPE: 12.815999999999999
# ==================================================
# Chengdu MNAR
# mean of MAE: 2.625
# mean of RMSE: 3.808
# mean of MAPE: 11.923
# ==================================================
# METR-LA MAR
# mean of MAE: 6.8725000000000005
# mean of RMSE: 12.0425
# mean of MAPE: 13.495999999999999
# ==================================================
# PEMS-BAY MNAR
# mean of MAE: 2.4635
# mean of RMSE: 4.686999999999999
# mean of MAPE: 5.519
# ==================================================
# Seattle MNAR
# mean of MAE: 3.9335
# mean of RMSE: 6.3055
# mean of MAPE: 11.026
# ==================================================
# Shenzhen MNAR
# mean of MAE: 2.5735
# mean of RMSE: 3.8819999999999997
# mean of MAPE: 11.075
# ==================================================

# %%
# MagiNet
import numpy as np

# Chengdu MAR
mae_list=[1.8831689357757568,1.9565743019637365,1.9311240496083362]
rmse_list=[2.802414894104004,2.8636595788049926,2.8780008763939993]
mape_list = [8.014038644148695,8.298046491299962,8.15577407236876]
print("Chengdu MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Chengdu MNAR
mae_list=[2.00931715965271,1.9541883636628903,1.915553754496474]
rmse_list=[2.9954216480255127,2.93491787556098,2.89678328288489]
mape_list = [8.617783367134214,8.369801128889282,8.107864803794579]
print("Chengdu MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# METR-LA MAR
mae_list=[2.6177053451538086,2.576127789126197,2.7540648438461037]
rmse_list=[5.304942607879639,5.12336578601256,5.613484149722599]
mape_list = [5.965346007007652,5.908656674259673,6.061457165073451]
print("METR-LA MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# METR-LA MNAR
mae_list=[2.556230306625366,2.5815220695024204]
rmse_list=[5.223241806030273,5.1992807175971265]
mape_list = [6.4203243984087,6.394209979456253]
print("METR-LA MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# PEMS-BAY MAR
mae_list=[0.8829885125160217,0.8276824138677624,0.8179558424964399]
rmse_list=[1.6302796602249146,1.466486338019652,1.4458101662374059]
mape_list = [1.8723122654666384,1.6188595160766432,1.5693385772456234]
print("PEMS-BAY MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# PEMS-BAY MNAR
mae_list=[0.9545013308525085,0.955329887112116,0.9581939851453855]
rmse_list=[1.8582704067230225,1.8824673406345558,1.8921860057589166]
mape_list = [1.8774453224251426,1.8734742227504948,1.8871834323453087]
print("PEMS-BAY MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Seattle MAR
mae_list=[2.07487154006958,2.075018438998529,2.094152473631232]
rmse_list=[3.191450834274292,3.1571401815009223,3.231030029933034]
mape_list = [4.846319699304398,4.821843487104611,4.872033914775553]
print("Seattle MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Seattle MNAR
mae_list=[2.1809661388397217,2.189987962617363,2.1930665685416697]
rmse_list=[3.396833658218384,3.3982755220274496,3.4303391834779466]
mape_list = [5.1679745564185335,5.174637964314922,5.197118940008249]
print("Seattle MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Shenzhen MAR
mae_list=[1.715789556503296,1.717666172204566,1.7326092856667192]
rmse_list=[2.5595462322235107,2.564276231296985,2.5833492110170884]
mape_list = [6.965421014232392,6.945750096998162,6.970659748307028]
print("Shenzhen MAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)

# Shenzhen MNAR
mae_list=[1.8335614204406738,1.815494005903967,1.8182708368375375]
rmse_list=[2.7702393531799316,2.7550631824521687,2.757605464517563]
mape_list = [7.456849380976941,7.460835598646417,7.481953168295606]
print("Shenzhen MNAR")
print("mean of MAE:", np.mean(mae_list))
print("mean of RMSE:", np.mean(rmse_list))
print("mean of MAPE:", np.mean(mape_list))
print("=" * 50)
# Out:
# Chengdu MAR
# mean of MAE: 1.9236224291159434
# mean of RMSE: 2.848025116434332
# mean of MAPE: 8.155953069272472
# ==================================================
# Chengdu MNAR
# mean of MAE: 1.959686425937358
# mean of RMSE: 2.9423742688237944
# mean of MAPE: 8.365149766606024
# ==================================================
# METR-LA MAR
# mean of MAE: 2.6492993260420366
# mean of RMSE: 5.347264181204932
# mean of MAPE: 5.978486615446926
# ==================================================
# METR-LA MNAR
# mean of MAE: 2.5688761880638933
# mean of RMSE: 5.2112612618137
# mean of MAPE: 6.407267188932476
# ==================================================
# PEMS-BAY MAR
# mean of MAE: 0.8428755896267415
# mean of RMSE: 1.5141920548273242
# mean of MAPE: 1.6868367862629683
# ==================================================
# PEMS-BAY MNAR
# mean of MAE: 0.95600840103667
# mean of RMSE: 1.8776412510388318
# mean of MAPE: 1.8793676591736486
# ==================================================
# Seattle MAR
# mean of MAE: 2.0813474842331137
# mean of RMSE: 3.193207015236083
# mean of MAPE: 4.846732367061521
# ==================================================
# Seattle MNAR
# mean of MAE: 2.188006889999585
# mean of RMSE: 3.4084827879079267
# mean of MAPE: 5.179910486913902
# ==================================================
# Shenzhen MAR
# mean of MAE: 1.7220216714581937
# mean of RMSE: 2.5690572248458614
# mean of MAPE: 6.9606102865125274
# ==================================================
# Shenzhen MNAR
# mean of MAE: 1.8224420877273928
# mean of RMSE: 2.7609693333832213
# mean of MAPE: 7.466546049306321
# ==================================================
